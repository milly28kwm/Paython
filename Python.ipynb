# %% [markdown]
# <a href="https://colab.research.google.com/github/milly28kwm/Paython/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **#aula 1** ♥ ✔ ⛓
#
# ![image.png](data:image/png;base64,...)
#  ![image.png](data:image/png;base64,...)
#  ![image.png](data:image/png;base64,...)

# %%
ano = "IX"
print(ano, "competição de programação dá Start")
# Out:
# IX competição de programação dá Start

# %% [markdown]
# **#aula 2** 🥰 ♒ ✈

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2* livro_ficcao + 5* livro_infantil
pontos_totais = pontos_ana + pontos_rodrigo
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais de ana são {pontos_ana}")
print(f"Os pontos totais do Robrigo e ana são {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais de ana são 46
# Os pontos totais do Robrigo e ana são 70
